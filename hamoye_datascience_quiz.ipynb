# %% [markdown]
# ## Import Relevant Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Loading the raw data

# %%
raw_data =pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding='latin-1')
raw_data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
raw_data.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
raw_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
raw_data.groupby('Y2014')['Y2014'].count()
# Out:
# Y2014
# -1796.0      1
# -1631.0      1
# -849.0       2
# -838.0       1
# -685.0       1
#             ..
#  90425.0     1
#  98094.0     1
#  108756.0    1
#  109593.0    1
#  176405.0    1
# Name: Y2014, Length: 4493, dtype: int64

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

# %%
data = pd.DataFrame(lst,columns=col,index=[1,2,3])
data
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
array  = np.array([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
array[1:,2]
# Out:
# array([48, 56])

# %%
len(raw_data)
# Out:
# 60943

# %%
S = [['him', 'sell'], [90, 28, 43]]

# %%
S[0][1][1]
# Out:
# 'e'

# %%
my_tuppy = (1,2,5,8)
my_tuppy[2]=6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24160/2659888410.py in <module>
#       1 my_tuppy = (1,2,5,8)
# ----> 2 my_tuppy[2]=6
#
# TypeError: 'tuple' object does not support item assignment

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
x=y[1][-1]
x
# Out:
# 8

# %%
raw_data.iloc[0:,]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# ## 11-20

# %%
raw_data.groupby('Item')['Y2014','Y2017'].sum()
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_24160/1203882050.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   raw_data.groupby('Item')['Y2014','Y2017'].sum()
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %%
raw_data['Y2015'].describe()
# Out:
# count     59395.000000
# mean        135.235966
# std        1603.403984
# min       -3161.000000
# 25%           0.000000
# 50%           0.080000
# 75%           8.460000
# max      181137.000000
# Name: Y2015, dtype: float64

# %%
raw_data['Y2016'].isnull().sum()
# Out:
# 1535

# %%
raw_data['Y2016'].isnull().sum()/(59395.000000)*100
# Out:
# 2.5843926256418888

# %% [markdown]
# ## question 20

# %%
raw_data['Area'].nunique()
# Out:
# 49

# %%
raw_data.groupby(['Element','Area'])['Y2018'].sum()
pd.set_option('display.max_rows', None)
raw_data.groupby(['Element','Area'])['Y2018'].sum()
# Out:
# Element                                 Area
# Domestic supply quantity                Algeria                         90023.42
#                                         Angola                          59590.22
#                                         Benin                           31447.90
#                                         Botswana                         3045.85
#                                         Burkina Faso                    25705.16
#                                         Cabo Verde                        731.00
#                                         Cameroon                        64009.74
#                                         Central African Republic         5567.06
#                                         Chad                            15489.73
#                                         Comoros                            19.95
#                                         Congo                            8524.55
# ...

# %%
raw_data.groupby(['Element'])['Y2014','Y2015','Y2016','Y2017'].sum()
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_24160/2776571075.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   raw_data.groupby(['Element'])['Y2014','Y2015','Y2016','Y2017'].sum()
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# ...

# %%
Fat supply quantity (g/capita/day)          10258.69
Seed                                        25263.14
Protein supply quantity (g/capita/day)      11833.56
Food supply (kcal/capita/day)              455261.00
Food supply quantity (kg/capita/yr)         49056.85
# Out:
#   File "C:\Users\USER\AppData\Local\Temp/ipykernel_24160/2777034485.py", line 1
#     Fat supply quantity (g/capita/day)          10258.69
#         ^
# SyntaxError: invalid syntax

# %%
raw_data.groupby(['Element'])['Y2014','Y2015','Y2016','Y2017'].sum()
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_24160/2776571075.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   raw_data.groupby(['Element'])['Y2014','Y2015','Y2016','Y2017'].sum()
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# ...
